# %% [markdown]
# What is the difference between hardware and software? Give one example of each.
# Hardware is the physical devices that are used to integrate with pc to deliver a task they rae specialised in.
# Software is the application which cannot be touched physically but can be used to maintain the pc base on the logic and rules defined.
